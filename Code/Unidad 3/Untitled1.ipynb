# %%
import pandas as pd
import numpy as np

# Creamos el DataFrame con datos aleatorios de Ecuador
df = pd.DataFrame({
    'Provincia': ['Azuay', 'Bolívar', 'Cañar', 'Carchi', 'Chimborazo', 'Cotopaxi', 'El Oro', 'Esmeraldas', 'Galápagos', 'Guayas', 'Imbabura', 'Loja', 'Los Ríos', 'Manabí', 'Morona Santiago', 'Napo', 'Orellana', 'Pastaza', 'Pichincha', 'Santa Elena', 'Santo Domingo de los Tsáchilas', 'Sucumbíos', 'Tungurahua', 'Zamora Chinchipe'],
    'Ciudad': ['Quito', 'Guayaquil', 'Cuenca', 'Santo Domingo', 'Machala', 'Durán', 'Loja', 'Manta', 'Esmeraldas', 'Portoviejo', 'Ambato', 'Quevedo', 'Riobamba', 'Milagro', 'Ibarra', 'Babahoyo', 'La Libertad', 'Ventanas', 'Pasaje', 'Chone', 'Santa Elena', 'Balzar', 'Nueva Loja', 'Zamora'],
    'Población': np.random.randint(50000, 5000000, size=23),
    'Tasa de natalidad': np.round(np.random.uniform(10, 30, size=23), 2),
    'Tasa de mortalidad': np.round(np.random.uniform(3, 12, size=23), 2)
})

# Exportamos el DataFrame a un archivo CSV
df.to_csv('datos1.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 5
#       2 import numpy as np
#       4 # Creamos el DataFrame con datos aleatorios de Ecuador
# ----> 5 df = pd.DataFrame({
#       6     'Provincia': ['Azuay', 'Bolívar', 'Cañar', 'Carchi', 'Chimborazo', 'Cotopaxi', 'El Oro', 'Esmeraldas', 'Galápagos', 'Guayas', 'Imbabura', 'Loja', 'Los Ríos', 'Manabí', 'Morona Santiago', 'Napo', 'Orellana', 'Pastaza', 'Pichincha', 'Santa Elena', 'Santo Domingo de los Tsáchilas', 'Sucumbíos', 'Tungurahua', 'Zamora Chinchipe'],
#       7     'Ciudad': ['Quito', 'Guayaquil', 'Cuenca', 'Santo Domingo', 'Machala', 'Durán', 'Loja', 'Manta', 'Esmeraldas', 'Portoviejo', 'Ambato', 'Quevedo', 'Riobamba', 'Milagro', 'Ibarra', 'Babahoyo', 'La Libertad', 'Ventanas', 'Pasaje', 'Chone', 'Santa Elena', 'Balzar', 'Nueva Loja', 'Zamora'],
# ...
